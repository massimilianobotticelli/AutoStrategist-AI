# %%
import pandas as pd
from pyspark.sql import SparkSession

# Define the path to the CSV file
csv_path = '/Volumes/workspace/car_sales/raw_data/vehicles.csv'

# Read the CSV file into a Spark DataFrame
vehicles_df = spark.read.option('header', True).option('inferSchema', True).csv(csv_path)
display(vehicles_df)

# %%
# Save the DataFrame as a table in the workspace.car_sales schema, only if it does not exist
vehicles_df.write.format('delta').mode('ignore').saveAsTable('workspace.car_sales.vehicles')

print('Table workspace.car_sales.vehicles created if it did not exist.')

# %%
# Display a sample of the imported table to verify
sample_df = spark.table('workspace.car_sales.vehicles')
display(sample_df.limit(20))
